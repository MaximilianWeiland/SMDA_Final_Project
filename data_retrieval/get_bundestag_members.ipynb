# %%
# load requirements
import pandas as pd
import xml.etree.ElementTree as ET
from atproto import Client

# %%
# parse the XML file
tree = ET.parse('../data/raw_data/MDB_STAMMDATEN.XML')
root = tree.getroot()

# %%
# dictionary comprehension to find the encoding of the latest election period
all_phases = {
    int(wp.findtext('WP'))
    for mdb in root.findall('MDB')
    for wp in mdb.findall('.//WAHLPERIODE')
    if wp.find('WP') is not None
}
latest_wp = max(all_phases)

# %%
# create the df by looping over all members

# create empty list to store the data
data = []

# now loop over all members and store relevant information
for mdb in root.findall("MDB"):

    # extract general information about the mp
    mdb_id = mdb.findtext("ID")
    name_element = mdb.find(".//NAME")
    first_name = name_element.findtext("VORNAME")
    surname = name_element.findtext("NACHNAME")
    acad_title = name_element.findtext("AKAD_TITEL")
    full_name = f"{acad_title} {first_name} {surname}".strip()
    bio_element = mdb.find("BIOGRAFISCHE_ANGABEN")
    birthdate = bio_element.findtext("GEBURTSDATUM")
    gender = bio_element.findtext("GESCHLECHT")
    party = bio_element.findtext("PARTEI_KURZ")
    profession = bio_element.findtext("BERUF")

    # check for participation in latest election period and append data if fits
    for wp in mdb.findall(".//WAHLPERIODE"):
        if int(wp.findtext("WP")) == latest_wp:
            # extract information about the specific election
            district_number = wp.findtext("WKR_NUMMER")
            district_name = wp.findtext("WKR_NAME")
            mandate = wp.findtext("MANDATSART")
            data.append({
                "id": mdb_id,
                "full_name": full_name,
                "birthdate": birthdate,
                "gender": gender,
                "party": party,
                "profession": profession,
                "district_number": district_number,
                "district_name": district_name,
                "mandate": mandate
            })

# convert this to a df and show the first rows
mps_df = pd.DataFrame(data).sort_values(by=["party", "full_name"])
mps_df.head()
# Out:
#            id           full_name   birthdate    gender party  \
# 512  11005504        Achim Köhler  22.03.1964  männlich   AfD
# 416  11005408         Adam Balten  09.11.1983  männlich   AfD
# 412  11005404  Alexander Arpaschi  24.05.1970  männlich   AfD
# 629  11005622   Alexis L. Giersch  25.09.1963  männlich   AfD
# 169  11004674       Andreas Bleck  17.04.1988  männlich   AfD
#
#                 profession district_number district_name      mandate
# 512                                    277  Rhein-Neckar  Landesliste
# 416  Mechatronik-Ingenieur             112       Wesel I  Landesliste
# 412                                    273       Rastatt  Landesliste
# 629                                                       Landesliste
# 169             Büroleiter             196       Neuwied  Landesliste

# %%
# create a client instance
client = Client()

# get the app password
with open("app_password.txt", "r") as f:
    app_password = f.read()

handle = "mxwlnd.bsky.social"

# login with my credentials
client.login(handle, app_password)
# Out:
# ProfileViewDetailed(did='did:plc:5sqqg66p7muc7ogbp6xx4sw6', handle='mxwlnd.bsky.social', associated=ProfileAssociated(chat=None, feedgens=0, labeler=False, lists=0, starter_packs=0, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:5sqqg66p7muc7ogbp6xx4sw6/bafkreigwrjedzb7jvmowkn6fbe2atbnlwecsa4ouk5wpz54eg6rqkvayrq@jpeg', banner=None, created_at='2025-05-19T19:28:35.738Z', description=None, display_name='', followers_count=2, follows_count=1, indexed_at='2025-05-19T19:28:35.738Z', joined_via_starter_pack=None, labels=[], pinned_post=None, posts_count=0, verification=None, viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewDetailed')

# %%
# define a function that gives me potential bsky handle
def find_first_handle(name):
    response = client.app.bsky.actor.search_actors({'term': name})
    actors = response["actors"]
    if len(actors) >= 1:
        handle = actors[0]["handle"]
    else:
        handle = ""

    return handle

# apply this to all names of MPs and stor result in new column
mps_df["potential_handle"] = mps_df["full_name"].apply(find_first_handle)

# %%
mps_df.head(20)
# Out:
#            id           full_name   birthdate    gender party  \
# 512  11005504        Achim Köhler  22.03.1964  männlich   AfD
# 416  11005408         Adam Balten  09.11.1983  männlich   AfD
# 412  11005404  Alexander Arpaschi  24.05.1970  männlich   AfD
# 629  11005622   Alexis L. Giersch  25.09.1963  männlich   AfD
# 169  11004674       Andreas Bleck  17.04.1988  männlich   AfD
# 532  11005524       Andreas Mayer  25.01.1995  männlich   AfD
# 548  11005540        Andreas Paul  10.10.1978  männlich   AfD
# 567  11005559       Angela Rudzka  20.01.1984  weiblich   AfD
# 557  11005549           Arne Raue  18.08.1970  männlich   AfD
# 603  11005596    Bastian Treuheit  17.01.1998  männlich   AfD
# 239  11004905      Beatrix Storch  27.05.1971  weiblich   AfD
# 367  11005203     Bernd Schattner  27.06.1968  männlich   AfD
# 585  11005578     Bernd Schuhmann  20.07.1964  männlich   AfD
# 423  11005415       Birgit Bessin  26.03.1978  weiblich   AfD
# 471  11005463       Boris Gamanov  19.10.1986  männlich   AfD
# 575  11005567      Carina Schießl  19.02.1990  weiblich   AfD
# 258  11005014    Carolin Bachmann  03.09.1988  weiblich   AfD
# 420  11005412      Carsten Becker  20.01.1990  männlich   AfD
# 450  11005442   Christian Douglas  26.01.1978  männlich   AfD
# 558  11005550      Christian Reck  16.11.1987  männlich   AfD
#
#                                             profession district_number  \
# 512                                                                277
# 416                              Mechatronik-Ingenieur             112
# 412                                                                273
# 629
# 169                                         Büroleiter             196
# 532               Luft- und Raumfahrttechnik-Ingenieur             253
# 548                         Offizier in der Bundeswehr              27
# 567  Referentin der AfD Fraktion im Landtag Nieders...              49
# 557                                                                 60
# 603                 Kaufmann im Groß- und Einzelhandel             242
# 239                                           Anwältin              85
# 367                                    Geschäftsführer             210
# 585                   Gärtnermeister, Gärtnertechniker             249
# 423                                                                 65
# 471                                Wirtschaftsfachwirt             296
# 575                                                                232
# 258                                                                160
# 420                                       Facharbeiter             297
# 450                                     Dipl.-Kaufmann             180
# 558           Kaufmann für Groß- und Außenhandel, B.A.             154
#
#                                          district_name      mandate  \
# 512                                       Rhein-Neckar  Landesliste
# 416                                            Wesel I  Landesliste
# 412                                            Rastatt  Landesliste
# 629                                                     Landesliste
# 169                                            Neuwied  Landesliste
# 532                                         Donau-Ries  Landesliste
# 548                              Oldenburg – Ammerland  Landesliste
# 567                          Salzgitter – Wolfenbüttel  Landesliste
# 557  BRB a.d.Havel– Potsdam-MittelmarkI –HVL III–Te...   Direktwahl
# 603                                              Fürth  Landesliste
# 239                                 Berlin-Lichtenberg  Landesliste
# 367                                           Südpfalz  Landesliste
# 585                                        Schweinfurt  Landesliste
# 423                Elbe-Elster – Oberspreewald-Lausitz   Direktwahl
# 471                                        Saarbrücken  Landesliste
# 575                                         Regensburg  Landesliste
# 258                                      Mittelsachsen   Direktwahl
# 420                                          Saarlouis  Landesliste
# 450                                        Main-Taunus  Landesliste
# 558                                             Meißen   Direktwahl
#
#                  potential_handle
# 512
# 416
# 412
# 629
# 169
# 532           qimmuno.bsky.social
# 548    andimicroscopy.bsky.social
# 567
# 557
# 603
# 239
# 367
# 585
# 423
# 471
# 575  heartflamestudio.bsky.social
# 258
# 420
# 450        crddouglas.bsky.social
# 558

# %%
# export the df to csv
mps_df.to_csv("../data/raw_data/bundestag_mps_potential_handle.csv")
